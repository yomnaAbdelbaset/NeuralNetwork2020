# %%
import tensorflow as tf
import numpy as np
N, D, H = 64, 1000, 100
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(H, input_shape=(D,), activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(D))
model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.SGD(lr=1e0))
x=np.random.randn(N, D)
y=np.random.randn(N, D)

history= model.fit(x, y, epochs=5000, batch_size=N)
# Out:
# Train on 64 samples
# Epoch 1/5000
# 64/64 [==============================] - 1s 9ms/sample - loss: 1.1713
# Epoch 2/5000
# 64/64 [==============================] - 0s 144us/sample - loss: 1.1318
# Epoch 3/5000
# 64/64 [==============================] - 0s 125us/sample - loss: 1.1013
# Epoch 4/5000
# 64/64 [==============================] - 0s 63us/sample - loss: 1.0772
# Epoch 5/5000
# 64/64 [==============================] - 0s 63us/sample - loss: 1.0576
# Epoch 6/5000
# 64/64 [==============================] - 0s 125us/sample - loss: 1.0415
# Epoch 7/5000
# 64/64 [==============================] - 0s 63us/sample - loss: 1.0279
# Epoch 8/5000
# 64/64 [==============================] - 0s 62us/sample - loss: 1.0165
# Epoch 9/5000
# 64/64 [==============================] - 0s 63us/sample - loss: 1.0066
# Epoch 10/5000
# 64/64 [==============================] - 0s 63us/sample - loss: 0.9982
# Epoch 11/5000
# 64/64 [==============================] - 0s 62us/sample - loss: 0.9909
# ...

# %%
input_layer=1
hidden_layer=2
output_layer=1

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1,input_shape=(1,),activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(hidden_layer))
model.add(tf.keras.layers.Dense(output_layer))

model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.SGD(lr=1e-5))
x=np.random.randn(100, 1)
y=np.random.randn(100, 1)

history= model.fit(x, y, epochs=50, batch_size=100)
# Out:
# Train on 100 samples
# Epoch 1/50
# 100/100 [==============================] - 1s 7ms/sample - loss: 0.8230
# Epoch 2/50
# 100/100 [==============================] - 0s 152us/sample - loss: 0.8224
# Epoch 3/50
# 100/100 [==============================] - 0s 40us/sample - loss: 0.8218
# Epoch 4/50
# 100/100 [==============================] - 0s 80us/sample - loss: 0.8212
# Epoch 5/50
# 100/100 [==============================] - 0s 80us/sample - loss: 0.8206
# Epoch 6/50
# 100/100 [==============================] - 0s 40us/sample - loss: 0.8200
# Epoch 7/50
# 100/100 [==============================] - 0s 80us/sample - loss: 0.8195
# Epoch 8/50
# 100/100 [==============================] - 0s 80us/sample - loss: 0.8189
# Epoch 9/50
# 100/100 [==============================] - 0s 40us/sample - loss: 0.8183
# Epoch 10/50
# 100/100 [==============================] - 0s 80us/sample - loss: 0.8178
# Epoch 11/50
# 100/100 [==============================] - 0s 80us/sample - loss: 0.8172
# ...

# %%
input_layer=1
hidden_layer1=3
hidden_layer2=3
output_layer=1

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(input_layer,input_shape=(1,),activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(hidden_layer1))
model.add(tf.keras.layers.Dense(hidden_layer2))
model.add(tf.keras.layers.Dense(output_layer))

model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.SGD(lr=1e0))
x=np.random.randn(100, 1)
y=np.random.randn(100, 1)

history= model.fit(x, y, epochs=50, batch_size=100)
# Out:
# Train on 100 samples
# Epoch 1/50
# 100/100 [==============================] - 1s 6ms/sample - loss: 1.2029
# Epoch 2/50
# 100/100 [==============================] - 0s 100us/sample - loss: 2.1786
# Epoch 3/50
# 100/100 [==============================] - 0s 80us/sample - loss: 1.5127
# Epoch 4/50
# 100/100 [==============================] - 0s 40us/sample - loss: 1360.0886
# Epoch 5/50
# 100/100 [==============================] - 0s 80us/sample - loss: 72631226846324719616.0000
# Epoch 6/50
# 100/100 [==============================] - 0s 40us/sample - loss: inf
# Epoch 7/50
# 100/100 [==============================] - 0s 40us/sample - loss: nan
# Epoch 8/50
# 100/100 [==============================] - 0s 80us/sample - loss: nan
# Epoch 9/50
# 100/100 [==============================] - 0s 80us/sample - loss: nan
# Epoch 10/50
# 100/100 [==============================] - 0s 80us/sample - loss: nan
# Epoch 11/50
# 100/100 [==============================] - 0s 80us/sample - loss: nan
# ...
